# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./DATA/CIA_Country_Facts.csv')
df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  2.270000e+02    2.270000e+02                  227.000000
# mean   2.874028e+07    5.982270e+05                  379.047137
# std    1.178913e+08    1.790282e+06                 1660.185825
# min    7.026000e+03    2.000000e+00                    0.000000
# 25%    4.376240e+05    4.647500e+03                   29.150000
# 50%    4.786994e+06    8.660000e+04                   78.800000
# 75%    1.749777e+07    4.418110e+05                  190.150000
# max    1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    227.000000     224.000000
# mean                      21.165330       0.038125
# std                       72.286863       4.889269
# min                        0.000000     -20.990000
# 25%                        0.100000      -0.927500
# 50%                        0.730000       0.000000
# ...

# %%
sns.histplot(data=df, x="Population", bins=50)
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.histplot(data=df[df["Population"] <= 500000000], x="Population")
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
plt.figure(figsize=(8, 3), dpi=200)
sns.barplot(data=df, y="GDP ($ per capita)", x="Region", estimator="std")
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(8, 4), dpi=200)
sns.scatterplot(data=df, x="Phones (per 1000)", y="GDP ($ per capita)", hue="Region")
plt.legend(bbox_to_anchor=(1.5,1));

# %%
plt.figure(figsize=(8, 4), dpi=200)
sns.scatterplot(data=df, x="Phones (per 1000)", y="Literacy (%)", hue="Region")
plt.legend(bbox_to_anchor=(1.5,1));

# %%
plt.figure(figsize=(10, 7), dpi=200)
sns.heatmap(df.corr(), annot=True, fmt=".2f", linewidths=1, linecolor="green");
# Out:
# C:\Users\MMucahitNAS\AppData\Local\Temp\ipykernel_18936\837778700.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, fmt=".2f", linewidths=1, linecolor="green");

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
df[df["Agriculture"].isnull()]["Country"]
# Out:
# 3            American Samoa
# 4                   Andorra
# 78                Gibraltar
# 80                Greenland
# 83                     Guam
# 134                 Mayotte
# 140              Montserrat
# 144                   Nauru
# 153      N. Mariana Islands
# 171            Saint Helena
# 174    St Pierre & Miquelon
# 177              San Marino
# 208       Turks & Caicos Is
# 221       Wallis and Futuna
# 223          Western Sahara
# Name: Country, dtype: object

# %%
df[df["Agriculture"].isnull()] = df[df["Agriculture"].isnull()].fillna(0,axis=0)

# %%
df[["Climate", "Region"]].groupby("Region").mean()
# Out:
#                                       Climate
# Region
# ASIA (EX. NEAR EAST)                 1.962963
# BALTICS                              3.000000
# C.W. OF IND. STATES                  2.550000
# EASTERN EUROPE                       3.111111
# LATIN AMER. & CARIB                  2.033333
# NEAR EAST                            1.666667
# NORTHERN AFRICA                      1.500000
# NORTHERN AMERICA                     1.500000
# OCEANIA                              2.000000
# SUB-SAHARAN AFRICA                   1.846939
# WESTERN EUROPE                       2.826087

# %%
df["Region"] = [i.strip() for i in df["Region"]]

# %%
df["Region"].unique()
# Out:
# array(['ASIA (EX. NEAR EAST)', 'EASTERN EUROPE', 'NORTHERN AFRICA',
#        'OCEANIA', 'WESTERN EUROPE', 'SUB-SAHARAN AFRICA',
#        'LATIN AMER. & CARIB', 'C.W. OF IND. STATES', 'NEAR EAST',
#        'NORTHERN AMERICA', 'BALTICS'], dtype=object)

# %%
df['Climate'] = df['Climate'].fillna(df.groupby('Region')['Climate'].transform('mean'))

# %%
df[df["Climate"].isnull()][["Climate", "Region"]]
# Out:
# Empty DataFrame
# Columns: [Climate, Region]
# Index: []

# %%
df['Literacy (%)'] = df['Literacy (%)'].fillna(df.groupby('Region')['Literacy (%)'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         1
# Infant mortality (per 1000 births)    1
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     2
# Arable (%)                            1
# Crops (%)                             1
# Other (%)                             1
# Climate                               0
# Birthrate                             1
# Deathrate                             2
# Agriculture                           0
# Industry                              1
# Service                               1
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.drop("Country", axis=1, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

X = pd.get_dummies(df)

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

# %%
ssd = []
for k in range(2, 30):
    model = KMeans(n_clusters=k)
    model.fit_predict(scaled_X)
    ssd.append(model.inertia_)
# Out:
# c:\Users\MMucahitNAS\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\MMucahitNAS\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\MMucahitNAS\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(2,30),ssd,'o--')
plt.xlabel("K Value")
plt.ylabel(" Sum of Squared Distances")
# Out:
# Text(0, 0.5, ' Sum of Squared Distances')
